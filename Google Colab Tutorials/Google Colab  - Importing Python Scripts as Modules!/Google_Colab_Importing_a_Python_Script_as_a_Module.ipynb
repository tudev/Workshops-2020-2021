# %%
from google.colab import files

# %% [markdown]
# # **Method I**

# %%
# !cp /content/drive/MyDrive/Colab\ Notebooks/TUDev\ +\ YouTube\ Vids/YouTube\ Vids/Importing\ Scripts\ as\ Modules/squareroot.py /content

# %%
import squareroot

# %%
squareroot.sqroot(5)
# Out:
# 2.23606797749979

# %% [markdown]
# # **Method II**

# %%
files.upload()
# Out:
#      <input type="file" id="files-044838ed-3f1f-4fe9-9519-5578db5d5a51" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-044838ed-3f1f-4fe9-9519-5578db5d5a51">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving squareroot.py to squareroot (1).py
# {'squareroot.py': b'# -*- coding: utf-8 -*-\n"""squareroot.ipynb\n\nAutomatically generated by Colaboratory.\n\nOriginal file is located at\n    https://colab.research.google.com/drive/1EVAzxDRf-iW0FdyKniLSpLEIM249q5Kd\n"""\n\ndef sqroot(x):\n  return x**.5'}

# %%
import squareroot

# %%
squareroot.sqroot(5)
# Out:
# 2.23606797749979
